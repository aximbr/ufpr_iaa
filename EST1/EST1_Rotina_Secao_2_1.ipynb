# %% [markdown]
# # Estatística 1 - Aula prática 2_1 em Python
#
# ## UNIDADE 2: Estatística descritiva
#
# ### Seção 2.1: Medidas de posição
#
# By Jose P. Leitão

# %%
# Importar bibliotecas
import pandas as pd

import numpy as np

from scipy.stats import mode

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Média

# %%
# Carrega a base salarios
salarios = pd.read_csv("salarios.csv")

# %%
# Exibe os primeiros registros
salarios.head()
# Out:
#    husage  husunion  husearns  huseduc  husblck  hushisp  hushrs  kidge6  \
# 0      42       0.0       568       14        0        0      40       1
# 1      26       0.0       600       14        0        0       0       0
# 2      56       0.0      1500       14        0        0      40       1
# 3      35       NaN         0       12        0        0      40       0
# 4      42       0.0       450       11        0        0      45       1
#
#    earns  age  ...  union  faminc  husexp  exper  kidlt6  hours  nwifeinc  \
# 0  290.0   43  ...    0.0   45000      22     23       0      0    29.920
# 1  654.0   26  ...    0.0   45000       6      6       0      0    10.992
# 2  100.0   49  ...    0.0   55000      36     31       0     15    49.800
# 3    0.0   35  ...    NaN   55000      17     19       1      0    55.000
# 4    0.0   43  ...    NaN   27500      25     24       0      0    27.500
#
#    inlf    hrwage    lwage
# 0     0       NaN      NaN
# 1     0       NaN      NaN
# 2     1  6.666667  1.89712
# 3     0       NaN      NaN
# 4     0       NaN      NaN
#
# [5 rows x 23 columns]

# %%
# Calculando a media dos rendimentos dos maridos
np.mean(salarios['husearns'])
# Out:
# np.float64(453.5406460773873)

# %%
# Calculando a media dos rendimentos das esposas
np.mean(salarios['earns'])
# Out:
# np.float64(232.8329783457579)

# %%
# A media do rendimento dos maridos na amostra eh US$453,5406
# A media do rendimento das esposas na amostra eh US$232,833

# se dividirmos o rendimento medio dos maridos pelo das esposas
# temos
print(f"{(453.5406/232.833)-1:.2%}")

# Portanto, o rendimento medio dos maridos eh quase o dobro do 
# rendimento medio das esposas (94,79% a mais)
# Out:
# 94.79%

# %% [markdown]
# #### Mediana

# %%
# Calculando a mediana dos rendimentos dos maridos
np.median(salarios['husearns'])
# Out:
# np.float64(418.5)

# %%
# Calculando a mediana dos rendimentos das esposas
np.median(salarios['earns'])
# Out:
# np.float64(185.0)

# %%
# A mediana do rendimento dos maridos eh de US$418,5
# A mediana do rendimento das esposas eh de US$185,0 

# Se dividirmos a mediana dos rendimentos dos maridos pelo das 
# esposas temos:
print(f"{(418.5/185)-1:.2%}")

# Em termos de mediana o rendimento dos maridos eh mais que o
# dobro do rendimento das esposas (126,22% a mais)
# Out:
# 126.22%

# %% [markdown]
# #### Moda

# %%
# Calculando as modas das idades dos maridos e esposas
print("A moda da idade para maridos é ",mode(salarios['husage'])[0], "anos, com ", mode(salarios['husage'])[1], "ocorrências")

print("A moda da idade para esposas é ",mode(salarios['age'])[0], "anos, com ", mode(salarios['age'])[1], "ocorrências")
# Out:
# A moda da idade para maridos é  44 anos, com  201 ocorrências
# A moda da idade para esposas é  37 anos, com  217 ocorrências

# %%
# Portanto, a moda da idade dos maridos eh maior que a das 
# esposas: 
print(f"{(44/37)-1:.2%}")
# eh aproximadamente 18,92% maior.
# Out:
# 18.92%
